# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# The Microsoft **C**ommon **O**bjects in **CO**ntext (MS COCO) dataset is a large-scale dataset for scene understanding.  The dataset is commonly used to train and benchmark object detection, segmentation, and captioning algorithms.
#
# ![Sample Dog Output](images/coco-examples.jpg)
#
# You can read more about the dataset on the [website](http://cocodataset.org/#home) or in the [research paper](https://arxiv.org/pdf/1405.0312.pdf).
#
# In this notebook, you will explore this dataset, in preparation for the project.
#
# ## Step 1: Initialize the COCO API
#
# We begin by initializing the [COCO API](https://github.com/cocodataset/cocoapi) that you will use to obtain the data.

# %%
# !zip -r  ./files_notebooks ./
# Out:
#   adding: 1_Preliminaries-zh.ipynb (deflated 71%)
#   adding: 1_Preliminaries.ipynb (deflated 76%)
#   adding: 0_Dataset-zh.ipynb (deflated 56%)
#   adding: __pycache__/ (stored 0%)
#   adding: __pycache__/vocabulary.cpython-36.pyc (deflated 51%)
#   adding: __pycache__/data_loader.cpython-36.pyc (deflated 50%)
#   adding: __pycache__/model.cpython-36.pyc (deflated 43%)
#   adding: 4_Zip Your Project Files and Submit.ipynb (deflated 61%)
#   adding: images/ (stored 0%)
#   adding: images/coco-examples.jpg (deflated 21%)
#   adding: images/encoder-decoder.png (deflated 18%)
#   adding: images/download_ex.png (deflated 13%)
#   adding: images/encoder.png (deflated 7%)
#   adding: images/decoder.png (deflated 32%)
#   adding: 3_Inference.ipynb (deflated 27%)
#   adding: training_log.txt (deflated 86%)
#   adding: data_loader.py (deflated 72%)
#   adding: 0_Dataset.ipynb (deflated 26%)
#   adding: 3_Inference-zh.ipynb (deflated 70%)
#   adding: model.py (deflated 64%)
#   adding: vocabulary.py (deflated 69%)
#   adding: 2_Training-zh.ipynb (deflated 63%)
#   adding: 4_Zip Your Project Files and Submit-zh.ipynb (deflated 49%)
#   adding: filelist.txt (deflated 2%)
#   adding: 2_Training.ipynb (deflated 68%)
#   adding: .ipynb_checkpoints/ (stored 0%)
#   adding: .ipynb_checkpoints/4_Zip Your Project Files and Submit-checkpoint.ipynb (deflated 61%)
#   adding: .ipynb_checkpoints/1_Preliminaries-checkpoint.ipynb (deflated 76%)
#   adding: .ipynb_checkpoints/4_Zip Your Project Files and Submit-zh-checkpoint.ipynb (deflated 49%)
#   adding: .ipynb_checkpoints/0_Dataset-checkpoint.ipynb (deflated 25%)
#   adding: .ipynb_checkpoints/3_Inference-zh-checkpoint.ipynb (deflated 70%)
#   adding: .ipynb_checkpoints/2_Training-zh-checkpoint.ipynb (deflated 63%)
#   adding: .ipynb_checkpoints/0_Dataset-zh-checkpoint.ipynb (deflated 56%)
#   adding: .ipynb_checkpoints/3_Inference-checkpoint.ipynb (deflated 27%)
#   adding: .ipynb_checkpoints/1_Preliminaries-zh-checkpoint.ipynb (deflated 71%)
#   adding: .ipynb_checkpoints/2_Training-checkpoint.ipynb (deflated 68%)
#   adding: vocab.pkl (deflated 50%)
#   adding: models/ (stored 0%)
#   adding: models/encoder-1.pkl (deflated 7%)
#   adding: models/256e-512h/ (stored 0%)
#   adding: models/256e-512h/encoder-1-Copy1.pkl (deflated 7%)
#   adding: models/256e-512h/decoder-1-Copy1.pkl (deflated 7%)
#   adding: models/decoder-1.pkl (deflated 7%)
#   adding: models/.ipynb_checkpoints/ (stored 0%)

# %%
import os
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO

# initialize COCO API for instance annotations
dataDir = '/opt/cocoapi'
dataType = 'val2014'
instances_annFile = os.path.join(dataDir, 'annotations/instances_{}.json'.format(dataType))
coco = COCO(instances_annFile)

# initialize COCO API for caption annotations
captions_annFile = os.path.join(dataDir, 'annotations/captions_{}.json'.format(dataType))
coco_caps = COCO(captions_annFile)

# get image ids 
ids = list(coco.anns.keys())
# Out:
# loading annotations into memory...
# Done (t=6.76s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.48s)
# creating index...
# index created!

# %% [markdown]
# ## Step 2: Plot a Sample Image
#
# Next, we plot a random image from the dataset, along with its five corresponding captions.  Each time you run the code cell below, a different image is selected.
#
# In the project, you will use this dataset to train your own model to generate captions from images!

# %%
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
# %matplotlib inline

# pick a random image and obtain the corresponding URL
ann_id = np.random.choice(ids)
img_id = coco.anns[ann_id]['image_id']
img = coco.loadImgs(img_id)[0]
url = img['coco_url']

# print URL and visualize corresponding image
print(url)
I = io.imread(url)
plt.axis('off')
plt.imshow(I)
plt.show()

# load and display captions
annIds = coco_caps.getAnnIds(imgIds=img['id']);
anns = coco_caps.loadAnns(annIds)
coco_caps.showAnns(anns)
# Out:
# http://images.cocodataset.org/val2014/COCO_val2014_000000538741.jpg
# A ski instructor is getting two people set up in their skis.
# Two people in a ski lesson check their equipment.
# Two skiers look at their skis with their instructor.
# A person with one ski on and one ski off talking to a couple wearing skis.
# Two individuals learning to ski along with an instructor

# %% [markdown]
# ## Step 3: What's to Come!
#
# In this project, you will use the dataset of image-caption pairs to train a CNN-RNN model to automatically generate images from captions.  You'll learn more about how to design the architecture in the next notebook in the sequence (**1_Preliminaries.ipynb**).
#
# ![Image Captioning CNN-RNN model](images/encoder-decoder.png)
